# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import requests
import json

# %%
#url="https://opensky-network.org/api/states/all?lamin=45.8389&lomin=5.9962&lamax=47.8229&lomax=10.5226"
url='https://opensky-network.org/api/states/all?icao24=e8027c'
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
print(responsehtml.decode())
type(responsehtml.decode())
# Out:
# {"time":1631032767,"states":null}
# str

# %%
len (responsehtml.decode())
info = json.loads(responsehtml.decode())
type(info)
len (info)
# Out:
# 2

# %%
import json
data = responsehtml.decode()
info = json.loads(data)
print("Tiempo:",info["time"])
print("Estados:",info["states"])
# Out:
# Tiempo: 1631031819
# Estados: [['a545d8', 'N439PF  ', 'United States', 1631031819, 1631031819, -119.148, 37.2037, 6576.06, False, 162.87, 53.35, 10.08, None, 7010.4, None, False, 0], ['e8027c', 'LPE2279 ', 'Chile', 1631031819, 1631031819, -77.4563, -11.3271, 3329.94, False, 155.76, 153.94, -7.15, None, 11635.74, None, False, 0], ['a2e5f5', 'N286TG  ', 'United States', 1631031672, 1631031672, -97.4571, 32.4074, 563.88, False, 50.27, 162.12, -0.33, None, 571.5, None, False, 0], ['a5a8e2', 'N464EG  ', 'United States', 1631031819, 1631031819, -120.5786, 44.847, 10668, False, 244.07, 107.29, 0, None, 11277.6, '6631', False, 0], ['e8027b', 'LAN573  ', 'Chile', 1631031619, 1631031622, -74.1529, 4.7118, None, True, 4.63, 340.31, None, None, None, None, False, 0], ['a7b08d', 'LXJ595  ', 'United States', 1631031816, 1631031816, -73.7174, 45.4713, None, True, 0.06, 219.38, None, None, None, None, False, 0], ['aa9321', 'UAL1010 ', 'United States', 1631031819, 1631031819, -66.9406, 31.077, 11277.6, False, 256.35, 170.18, -0.33, None, 11887.2, None, False, 0], ['ade18c', 'AAL2655 ', 'United States', 1631031819, 1631031819, -111.0283, 40.334, 10363.2, False, 228.87, 305.76, 0, None, 11010.9, None, False, 0], ['a77ec5', 'EJA582  ', 'United States', 1631031772, 1631031777, -89.3272, 43.1399, None, True, 0, 180, None, None, None, None, False, 0], ['a4ab0e', 'N40HY   ', 'United States', 1631031819, 1631031819, -97.3026, 33.186, 579.12, False, 47.16, 96.89, 0.33, None, 594.36, None, False, 0], ['a9f068', 'N74CE   ', 'United States', 1631031819, 1631031819, -86.7668, 34.6131, 403.86, False, 68.49, 182.58, 3.9, None, 411.48, None, False, 0], ['a305fd', 'SKW3646 ', 'United States', 1631031578, 1631031579, -111.9813, 40.79, None, True, 0, 84.38, None, None, None, None, False, 0], ['4b1803', 'SWR54M  ', 'Switzerland', 1631031819, 1631031819, 14.4169, 44.0602, 11277.6, False, 232.08, 134.82, 0, None, 11635.74, '3067', False, 0], ['4b1804', 'SWR240J ', 'Switzerland', 1631031819, 1631031819, 9.2656, 49.1068, 11285.22, False, 193.21, 16.55, 4.88, None, 11780.52, '3012', False, 0], ['4b1805', 'SWR56M  ', 'Switzerland', 1631031819, 1631031819, 4.2471, 47.7164, 10325.1, False, 234.13, 324.39, 4.55, None, 10843.26, '5776', False, 0], ['a60540', 'N4872H  ', 'United States', 1631031600, 1631031600, -117.1317, 32.8117, None, True, 4.63, 59.06, None, None, None, None, False, 0], ['4b1807', 'SWR129L ', 'Switzerland', 1631031819, 1631031819, 9.4141, 49.6005, 11071.86, False, 206.86, 1.28, 3.58, None, 11567.16, '3002', False, 0], ['4b1808', 'SWR194P ', 'Switzerland', 1631031819, 1631031819, 14.2482, 46.5689, 10668, False, 242.4, 108.43, 0, None, 11010.9, '3056', False, 0], ['4b1809', 'SWR441A ', 'Switzerland', 1631031819, 1631031819, 12.074, 42.0951, 1478.28, False, 133.68, 132.04, -7.15, None, 1638.3, '1000', False, 0], ['aa56d5', 'UAL2279 ', 'United States', 1631031686, 1631031686, -118.418, 33.9369, None, True, 4.89, 84.38, None, None, None, '6665', False, 0], ['a2cbbd', 'N28BB   ', 'United States', 1631031819, 1631031819, -73.0735, 40.6978, 746.76, False, 71.61, 245.83, 0.33, None, 762, None, False, 0], ['a3687e', 'AJT881  ', 'United States', 1631031819, 1631031819, -77.1564, 35.9766, 9753.6, False, 242.4, 208.52, 0.33, None, 10241.28, '1665', False, 0], ['4b1802', 'SWR407  ', 'Switzerland', 1631031818, 1631031818, 8.558, 47.4496, None, True, 5.4, 120.94, None, None, None, '2050', False, 0], ['a798c6', 'EJA589  ', 'United States', 1631031817, 1631031819, -119.7761, 39.8034, 11887.2, False, 215.11, 26.57, -0.65, None, 12557.76, None, False, 0], ['a5820f', 'N454MD  ', 'United States', 1631031819, 1631031819, -98.7302, 29.9145, 1219.2, False, 55.48, 341.06, -0.33, None, 1303.02, None, False, 0], ['a1fb50', 'N227DC  ', 'United States', 1631031819, 1631031819, -120.057, 36.9727, 2164.08, False, 94.86, 306.62, 3.25, None, 2278.38, None, False, 0], ['51111d', 'ART1238 ', 'Estonia', 1631031819, 1631031819, 8.7972, 45.937, 11277.6, False, 233.11, 149.64, 0, None, 11727.18, '1142', False, 0], ...

# %%
url="https://opensky-network.org/api/states/all"
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
data = responsehtml.decode()

# %%
info = json.loads(data)
#print("Tiempo:",info["time"])
#print("Estados:",info["states"])
df=pd.DataFrame(info["states"])
print(df)
# Out:
#           0         1              2             3           4         5   \
# 0     a5a8e2  N464EG    United States  1.631033e+09  1631033239 -116.6893
# 1     e8027b  LAN573            Chile  1.631032e+09  1631033037  -74.1475
# 2     e8027d  LPE2063           Chile  1.631033e+09  1631033239  -76.0077
# 3     a6fe0e  N55LB     United States  1.631033e+09  1631033239  -86.1490
# 4     a7b08d  LXJ595    United States  1.631033e+09  1631033239  -73.8147
# ...      ...       ...            ...           ...         ...       ...
# 8025  c04da8  CGDKP            Canada  1.631033e+09  1631032977  -68.2043
# 8026  0ac9c3  VVC5854        Colombia  1.631033e+09  1631033236  -78.9503
# 8027  a9607d  JBU1497   United States  1.631033e+09  1631033239  -79.6785
# 8028  c067ae  ACA305           Canada  1.631033e+09  1631033231  -73.7460
# 8029  a41b89  DAL1023   United States  1.631033e+09  1631033239  -91.6835
#
#            6         7      8       9       10     11    12        13    14  \
# 0     43.8300   3360.42  False  181.34  129.24 -13.66  None   3550.92  6631
# 1      4.7099       NaN   True  237.04  220.95   6.83  None       NaN  None
# 2    -12.7234   8336.28  False  226.16  116.04   7.15  None   1470.66  None
# 3     30.7937   5364.48  False  183.96    6.91  13.33  None   5631.18  None
# 4     43.4834  13106.40  False  228.94  179.36  -0.33  None  13456.92  0677
# ...       ...       ...    ...     ...     ...    ...   ...       ...   ...
# 8025  45.3262   3360.42  False   89.61   87.37   0.00  None   3345.18  None
# 8026   9.5534  10988.04  False  237.90  315.00   0.33  None  11711.94  None
# 8027  40.1713   9753.60  False  217.10  270.41   0.00  None  10180.32  2612
# 8028  45.4588       NaN   True    0.06  177.19    NaN  None       NaN  1367
# 8029  34.3761  10675.62  False  244.56  114.08   0.00  None  11231.88  3127
#
#          15  16
# 0     False   0
# 1     False   0
# 2     False   0
# 3     False   0
# 4     False   0
# ...     ...  ..
# 8025  False   0
# 8026  False   0
# 8027  False   0
# 8028  False   0
# 8029  False   0
#
# [8030 rows x 17 columns]

# %%
col_name=['icao24','callsign','origin_country','time_position','last_contact','long','lat','baro_altitude','on_ground','velocity',       
'true_track','vertical_rate','sensors','geo_altitude','squawk','spi','position_source']
pd.DataFrame(info['states'],columns=col_name)
# Out:
#       icao24  callsign origin_country  time_position  last_contact      long  \
# 0     a808c4  PDT6234   United States   1.615773e+09    1615773432  -77.3200
# 1     7c6b2f  JST512        Australia   1.615773e+09    1615773366  144.8423
# 2     88044f  AIQ4324        Thailand   1.615773e+09    1615773491  100.6486
# 3     7c6b41  JST945        Australia   1.615774e+09    1615773509  145.1225
# 4     7c6b40  JST564        Australia   1.615774e+09    1615773509  149.2732
# ...      ...       ...            ...            ...           ...       ...
# 3282  a81837  N620WF    United States   1.615774e+09    1615773509 -115.0230
# 3283  a9b053  BTQ496    United States   1.615774e+09    1615773509  -92.7195
# 3284  7808f7  HXA2763           China   1.615773e+09    1615773507  106.9224
# 3285  4403f4  TAY4037         Austria   1.615774e+09    1615773509    3.5794
# 3286  a09a04  N138MH    United States   1.615773e+09    1615773294  -77.0423
#
#           lat  baro_altitude  on_ground  velocity  true_track  vertical_rate  \
# 0     40.8152        1272.54      False    112.54      317.78          -1.95
# 1    -37.6701            NaN       True     10.29      351.56            NaN
# 2     12.1325        9509.76      False    228.07      177.80           7.48
# 3    -36.2436        9113.52      False    224.29      211.68         -11.05
# 4    -32.9154       10668.00      False    239.95       37.51           0.00
# ...       ...            ...        ...       ...         ...            ...
# 3282  35.5516        4564.38      False     96.47       15.15           0.00
# 3283  33.2983        5684.52      False    169.74       82.34          -6.18
# 3284  28.6567        9784.08      False    223.56      177.10          -0.33
# 3285  49.0881       10035.54      False    234.60      208.70          -0.33
# 3286  38.6474         236.22      False     69.72      205.81           0.33
#
#      sensors  geo_altitude squawk    spi  position_source
# 0       None       1280.16   7263  False                0
# 1       None           NaN   None  False                0
# 2       None      10111.74   None  False                0
# 3       None       9517.38   1151  False                0
# 4       None      11087.10   1402  False                0
# ...      ...           ...    ...    ...              ...
# 3282    None       4655.82   7224  False                0
# 3283    None       5890.26   2357  False                0
# 3284    None       7741.92   6447  False                0
# 3285    None           NaN   7140  False                0
# 3286    None        266.70   2224  False                0
#
# [3287 rows x 17 columns]

# %%
#NOTA:
# Averiguar sobre la librería OpenSkyApi 
#import OpenSkyApi
